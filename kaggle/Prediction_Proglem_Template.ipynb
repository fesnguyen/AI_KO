# %% [markdown]
# # Prediction Problem Template

# %%
# ======================
# IMPORTS
# ======================

import pandas as pd
import numpy as np
import math

# %%
# ======================
# CONFIG
# ======================

# %xmode Context
# Out:
# Exception reporting mode: Context

# %%
# ======================
# LOAD DATA
# ======================


def load_data():
    """
    Load and correct data
    
    - Rename columns for consistence and convenient
    - Correct dtypes
    """
    df = pd.read_csv('')

    
    return df

# %%
# ======================
# EDA
# ======================

df.info()
